-- %% [markdown]
-- # 2\. Modifying Data

-- %% [markdown]
-- ## Task 2.1 Setup
--
-- 1. Run the following script on your own DB.
-- 2. Important: Enter the name of your DB after USE

-- %%
USE mge9869
GO

CREATE TABLE Credit
(CustomerID int Primary Key IDENTITY
  , Firstname char(20) NOT NULL
  , Lastname char(20) NOT NULL
  , CreditLimit int DEFAULT 0 NOT NULL
  , Email char(20) NULL);
  
  GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.023

-- %% [markdown]
-- ## Task 2.2 Inserting Data
--
-- Show all data from Credit table
--
-- Add data to credit table Izak, Cohen, Creditlimit: 5000, E-Mail: [izak@adatum.com](mailto:izak@adatum.com)

-- %% [markdown]
-- Execute the following statement.
--
-- Where does the value of DEFAULT come from?

-- %%
INSERT INTO Credit VALUES ('David', 'Hamilton', DEFAULT, NULL);

-- %% [markdown]
-- Why does the following statement fail and what needs to be done to correct it?

-- %%
INSERT INTO Credit VALUES ('Don', 'Hall', 5000);

-- %% [markdown]
-- Insert some more Data:
--
-- Don Hall Creditlimit 5000
--
-- Punya Palit Creditlimit 10000

-- %% [markdown]
-- Show all the Data

-- %% [markdown]
-- ## Task 2.3 Update Data
--
-- - Set the email from customer 4 to [punya@adatum.com](mailto:punya@adatum.com)
-- - Rise the creditlimit for 500$ for every customer

-- %% [markdown]
-- ## Task 2.4 Delete Data
--
-- - Delete all entrys from Customer Nr. 4
-- - Delete all lines from Credit table. Useboth ways to achive that
-- - Which way is more efficient?
