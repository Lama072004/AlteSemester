-- %% [markdown]
-- # 1\. Simple SQL query statements

-- %%
USE AdventureWorks2017;

SELECT * FROM Production.ProductSubcategory;

-- %% [markdown]
-- ## Task 1.2
--
-- Only display the following columns from Production.ProductSubcategory
--
-- - ProductSubcategoryID,
-- - ProductCategoryID,
-- - Name,
-- - ModifiedDate

-- %% [markdown]
-- ## Task 1.3
--
-- Extend the query from 1.2 so that you only show the entries that have "Bike" in their name.

-- %% [markdown]
-- ## Task 1.4
--
-- Extends the query from 1.3 so that the Name column is now called "Subcategory Name".

-- %% [markdown]
-- ## Task 1.5
--
-- Extends the query from 1.4 so that the data is sorted alphabetically according to the contents of the "Subcategory Name" column.
